// %% [markdown]
// # Kotlin UI DSL
//
// This notebook renders a basic UI element created using the [Kotlin UI DSL](https://plugins.jetbrains.com/docs/intellij/kotlin-ui-dsl-version-2.html).

// %%
%use intellij-platform

// %%
import com.intellij.ui.dsl.builder.panel
import com.intellij.util.ui.JBUI

panel {
    row {
        checkBox("Check me!")
            .comment("A comment for this checkbox")
    }
}.apply {
    size = JBUI.size(500, 200)
    border = JBUI.Borders.empty(10, 20)
}

// %% [markdown]
// _Note: defining the `size` property is mandatory for rendering Swing components in the cell answer._
